# %%
#!/usr/bin/python
"""
Octree implementation
"""
# From: https://code.google.com/p/pynastran/source/browse/trunk/pyNastran/general/octree.py?r=949
#       http://code.activestate.com/recipes/498121-python-octree-implementation/

# UPDATED:
# Is now more like a true octree (ie: partitions space containing objects)

# Important Points to remember:
# The OctNode positions do not correspond to any object position
# rather they are seperate containers which may contain objects
# or other nodes.

# An OctNode which which holds less objects than MAX_OBJECTS_PER_CUBE
# is a LeafNode; it has no branches, but holds a list of objects contained within
# its boundaries. The list of objects is held in the leafNode's 'data' property

# If more objects are added to an OctNode, taking the object count over MAX_OBJECTS_PER_CUBE
# Then the cube has to subdivide itself, and arrange its objects in the new child nodes.
# The new octNode itself contains no objects, but its children should.

from __future__ import print_function

try:
    import numpy as np
except ImportError:
    np = None


class OctNode(object):
    """
    New Octnode Class, can be appended to as well i think
    """
    def __init__(self, position, size, depth, data):
        """
        OctNode Cubes have a position and size
        position is related to, but not the same as the objects the node contains.
        Branches (or children) follow a predictable pattern to make accesses simple.
        Here, - means less than 'origin' in that dimension, + means greater than.
        branch: 0 1 2 3 4 5 6 7
        x:      - - - - + + + +
        y:      - - + + - - + +
        z:      - + - + - + - +
        """
        self.position = position
        self.size = size
        self.depth = depth

        ## All OctNodes will be leaf nodes at first
        ## Then subdivided later as more objects get added
        self.isLeafNode = True

        ## store our object, typically this will be one, but maybe more
        self.data = data

        ## might as well give it some emtpy branches while we are here.
        self.branches = [None, None, None, None, None, None, None, None]

        half = size / 2

        ## The cube's bounding coordinates
        self.lower = (position[0] - half, position[1] - half, position[2] - half)
        self.upper = (position[0] + half, position[1] + half, position[2] + half)

    def __str__(self):
        data_str = u", ".join((str(x) for x in self.data))
        return u"position: {0}, size: {1}, depth: {2} leaf: {3}, data: {4}".format(
            self.position, self.size, self.depth, self.isLeafNode, data_str
        )


class Octree(object):
    """
    The octree itself, which is capable of adding and searching for nodes.
    """
    def __init__(self, worldSize, origin=(0, 0, 0), max_type="nodes", max_value=10):
        """
        Init the world bounding root cube
        all world geometry is inside this
        it will first be created as a leaf node (ie, without branches)
        this is because it has no objects, which is less than MAX_OBJECTS_PER_CUBE
        if we insert more objects into it than MAX_OBJECTS_PER_CUBE, then it will subdivide itself.
        """
        self.root = OctNode(origin, worldSize, 0, [])
        self.worldSize = worldSize
        self.limit_nodes = (max_type=="nodes")
        self.limit = max_value

    @staticmethod
    def CreateNode(position, size, objects):
        """This creates the actual OctNode itself."""
        return OctNode(position, size, objects)

    def insertNode(self, position, objData=None):
        """
        Add the given object to the octree if possible
        Parameters
        ----------
        position : array_like with 3 elements
            The spatial location for the object
        objData : optional
            The data to store at this position. By default stores the position.
            If the object does not have a position attribute, the object
            itself is assumed to be the position.
        Returns
        -------
        node : OctNode or None
            The node in which the data is stored or None if outside the
            octree's boundary volume.
        """
        if np:
            if np.any(position < self.root.lower):
                return None
            if np.any(position > self.root.upper):
                return None
        else:
            if position < self.root.lower:
                return None
            if position > self.root.upper:
                return None

        if objData is None:
            objData = position

        return self.__insertNode(self.root, self.root.size, self.root, position, objData)

    def __insertNode(self, root, size, parent, position, objData):
        """Private version of insertNode() that is called recursively"""
        if root is None:
            # we're inserting a single object, so if we reach an empty node, insert it here
            # Our new node will be a leaf with one object, our object
            # More may be added later, or the node maybe subdivided if too many are added
            # Find the Real Geometric centre point of our new node:
            # Found from the position of the parent node supplied in the arguments
            pos = parent.position

            ## offset is halfway across the size allocated for this node
            offset = size / 2

            ## find out which direction we're heading in
            branch = self.__findBranch(parent, position)

            ## new center = parent position + (branch direction * offset)
            newCenter = (0, 0, 0)

            if branch == 0:
                newCenter = (pos[0] - offset, pos[1] - offset, pos[2] - offset )
            elif branch == 1:
                newCenter = (pos[0] - offset, pos[1] - offset, pos[2] + offset )
            elif branch == 2:
                newCenter = (pos[0] - offset, pos[1] + offset, pos[2] - offset )
            elif branch == 3:
                newCenter = (pos[0] - offset, pos[1] + offset, pos[2] + offset )
            elif branch == 4:
                newCenter = (pos[0] + offset, pos[1] - offset, pos[2] - offset )
            elif branch == 5:
                newCenter = (pos[0] + offset, pos[1] - offset, pos[2] + offset )
            elif branch == 6:
                newCenter = (pos[0] + offset, pos[1] + offset, pos[2] - offset )
            elif branch == 7:
                newCenter = (pos[0] + offset, pos[1] + offset, pos[2] + offset )

            # Now we know the centre point of the new node
            # we already know the size as supplied by the parent node
            # So create a new node at this position in the tree
            # print "Adding Node of size: " + str(size / 2) + " at " + str(newCenter)
            return OctNode(newCenter, size, parent.depth + 1, [objData])

        #else: are we not at our position, but not at a leaf node either
        elif (
            not root.isLeafNode
            and
            (
                (np and np.any(root.position != position))
                or
                (root.position != position)
            )
        ):

            # we're in an octNode still, we need to traverse further
            branch = self.__findBranch(root, position)
            # Find the new scale we working with
            newSize = root.size / 2
            # Perform the same operation on the appropriate branch recursively
            root.branches[branch] = self.__insertNode(root.branches[branch], newSize, root, position, objData)

        # else, is this node a leaf node with objects already in it?
        elif root.isLeafNode:
            # We've reached a leaf node. This has no branches yet, but does hold
            # some objects, at the moment, this has to be less objects than MAX_OBJECTS_PER_CUBE
            # otherwise this would not be a leafNode (elementary my dear watson).
            # if we add the node to this branch will we be over the limit?
            if (
                (self.limit_nodes and len(root.data) < self.limit)
                or
                (not self.limit_nodes and root.depth >= self.limit)
            ):
                # No? then Add to the Node's list of objects and we're done
                root.data.append(objData)
                #return root
            else:
                # Adding this object to this leaf takes us over the limit
                # So we have to subdivide the leaf and redistribute the objects
                # on the new children.
                # Add the new object to pre-existing list
                root.data.append(objData)
                # copy the list
                objList = root.data
                # Clear this node's data
                root.data = None
                # It is not a leaf node anymore
                root.isLeafNode = False
                # Calculate the size of the new children
                newSize = root.size / 2
                # distribute the objects on the new tree
                # print "Subdividing Node sized at: " + str(root.size) + " at " + str(root.position)
                for ob in objList:
                    # Use the position attribute of the object if possible
                    if hasattr(ob, "position"):
                        pos = ob.position
                    else:
                        pos = ob
                    branch = self.__findBranch(root, pos)
                    root.branches[branch] = self.__insertNode(root.branches[branch], newSize, root, pos, ob)
        return root

    def findPosition(self, position):
        """
        Basic lookup that finds the leaf node containing the specified position
        Returns the child objects of the leaf, or None if the leaf is empty or none
        """
        if np:
            if np.any(position < self.root.lower):
                return None
            if np.any(position > self.root.upper):
                return None
        else:
            if position < self.root.lower:
                return None
            if position > self.root.upper:
                return None
        return self.__findPosition(self.root, position)

    @staticmethod
    def __findPosition(node, position, count=0, branch=0):
        """Private version of findPosition """
        if node.isLeafNode:
            #print("The position is", position, " data is", node.data)
            return node.data
        branch = Octree.__findBranch(node, position)
        child = node.branches[branch]
        if child is None:
            return None
        return Octree.__findPosition(child, position, count + 1, branch)

    @staticmethod
    def __findBranch(root, position):
        """
        helper function
        returns an index corresponding to a branch
        pointing in the direction we want to go
        """
        index = 0
        if (position[0] >= root.position[0]):
            index |= 4
        if (position[1] >= root.position[1]):
            index |= 2
        if (position[2] >= root.position[2]):
            index |= 1
        return index

    def iterateDepthFirst(self):
        """Iterate through the octree depth-first"""
        gen = self.__iterateDepthFirst(self.root)
        for n in gen:
            yield n

    @staticmethod
    def __iterateDepthFirst(root):
        """Private (static) version of iterateDepthFirst"""

        for branch in root.branches:
            if branch is None:
                continue
            for n in Octree.__iterateDepthFirst(branch):
                yield n
            if branch.isLeafNode:
                yield branch

## ---------------------------------------------------------------------------------------------------##


if __name__ == "__main__":

    ### Object Insertion Test ###

    # So lets test the adding:
    import random
    import time

    class TestObject(object):
        """Dummy object class to test with"""
        def __init__(self, name, position):
            self.name = name
            self.position = position

        def __str__(self):
            return u"name: {0} position: {1}".format(self.name, self.position)

    # Number of objects we intend to add.
    NUM_TEST_OBJECTS = 2000

    # Number of lookups we're going to test
    NUM_LOOKUPS = 2000

    # Size that the octree covers
    WORLD_SIZE = 100.0

    #ORIGIN = (WORLD_SIZE, WORLD_SIZE, WORLD_SIZE)
    ORIGIN = (0, 0, 0)

    # The range from which to draw random values
    RAND_RANGE = (-WORLD_SIZE * 0.3, WORLD_SIZE * 0.3)

    # create random test objects
    testObjects = []
    for x in range(NUM_TEST_OBJECTS):
        the_name = "Node__" + str(x)
        the_pos = (
            ORIGIN[0] + random.randrange(*RAND_RANGE),
            ORIGIN[1] + random.randrange(*RAND_RANGE),
            ORIGIN[2] + random.randrange(*RAND_RANGE)
        )
        testObjects.append(TestObject(the_name, the_pos))

    # create some random positions to find as well
    findPositions = []
    for x in range(NUM_LOOKUPS):
        the_pos = (
            ORIGIN[0] + random.randrange(*RAND_RANGE),
            ORIGIN[1] + random.randrange(*RAND_RANGE),
            ORIGIN[2] + random.randrange(*RAND_RANGE)
        )
        findPositions.append(the_pos)

    test_trees = (
        ("nodes", 10),
        ("depth", 5)
    )

    for tree_params in test_trees:

        # Create a new octree, size of world
        myTree = Octree(
            WORLD_SIZE,
            ORIGIN,
            max_type=tree_params[0],
            max_value=tree_params[1]
        )

        # Insert some random objects and time it
        Start = time.time()
        for testObject in testObjects:
            myTree.insertNode(testObject.position, testObject)
        End = time.time() - Start

        # print some results.
        print(NUM_TEST_OBJECTS, "Node Tree Generated in", End, "Seconds")
        print("Tree centered at", ORIGIN, "with size", WORLD_SIZE)
        if myTree.limit_nodes:
            print("Tree Leaves contain a maximum of", myTree.limit, "objects each.")
        else:
            print("Tree has a maximum depth of", myTree.limit)

        print("Depth First")
        for i, x in enumerate(myTree.iterateDepthFirst()):
            print(i, ":", x)

        ### Lookup Tests ###

        # # Looking up values outside the octree's value set should return None
        # result = myTree.findPosition((
        #     ORIGIN[0] + WORLD_SIZE * 1.1,
        #     ORIGIN[1] + WORLD_SIZE,
        #     ORIGIN[2] + WORLD_SIZE
        # ))
        # assert(result is None)

        # Look up some random positions and time it
        # Start = time.time()
        # for the_pos in findPositions:
        #     result = myTree.findPosition(the_pos)

        #     ##################################################################################
        #     # This proves that results are being returned - but may result in a large printout
        #     # I'd just comment it out and trust me :)
        #     if result is None:
        #         print("No result for test at:", the_pos)
        #     else:
        #         print("Results for test at:", the_pos)
        #         if result is not None:
        #             for i in result:
        #                 print("    ", i.name, i.position)
        #         print()
        #     ##################################################################################

        # End = time.time() - Start

        # # print some results.
        # print(str(NUM_LOOKUPS), "Lookups performed in", End, "Seconds")
# Out:
# 2000 Node Tree Generated in 0.06170058250427246 Seconds
# Tree centered at (0, 0, 0) with size 100.0
# Tree Leaves contain a maximum of 10 objects each.
# Depth First
# 0 : position: (-37.5, -37.5, -12.5), size: 25.0, depth: 2 leaf: True, data: name: Node__275 position: (-28, -26, -10), name: Node__487 position: (-28, -30, -9), name: Node__552 position: (-27, -29, -5), name: Node__629 position: (-30, -28, -9), name: Node__1046 position: (-29, -26, -3), name: Node__1140 position: (-29, -28, -4), name: Node__1214 position: (-30, -28, -12), name: Node__1590 position: (-26, -29, -14)
# 1 : position: (-37.5, -12.5, -37.5), size: 25.0, depth: 2 leaf: True, data: name: Node__344 position: (-28, -20, -26), name: Node__579 position: (-27, -14, -29), name: Node__680 position: (-29, -15, -27), name: Node__901 position: (-27, -6, -30), name: Node__1554 position: (-26, -24, -27), name: Node__1652 position: (-27, -7, -28)
# 2 : position: (-31.25, -18.75, -18.75), size: 12.5, depth: 3 leaf: True, data: name: Node__451 position: (-30, -18, -23), name: Node__463 position: (-26, -15, -18), name: Node__528 position: (-28, -25, -16), name: Node__840 position: (-29, -15, -19), name: Node__1668 position: (-26, -17, -15), name: Node__1687 position: (-30, -14, -18), name: Node__1907 position: (-30, -14, -22)
# 3 : position: (-31.25, -18.75, -6.25), size: 12.5, depth: 3 leaf: True, data: name: Node__441 position: (-29, -24, -11), name: Node__672 position: (-28, -23, -6), name: Node__1796 position: (-29, -20, -9)
# 4 : position: (-31.25, -6.25, -18.75), size: 12.5, depth: 3 leaf: True, data: name: Node__603 position: (-26, -7, -14), name: Node__882 position: (-26, -1, -16), name: Node__1598 position: (-30, -2, -20), name: Node__1649 position: (-26, -7, -23), name: Node__1698 position: (-30, -9, -16), name: Node__1721 position: (-30, -11, -15), name: Node__1762 position: (-28, -8, -22), name: Node__1977 position: (-28, -7, -19)
# 5 : position: (-31.25, -6.25, -6.25), size: 12.5, depth: 3 leaf: True, data: name: Node__538 position: (-26, -6, -11), name: Node__605 position: (-28, -3, -4), name: Node__855 position: (-27, -11, -2), name: Node__1316 position: (-29, -5, -8), name: Node__1441 position: (-27, -2, -4)
# 6 : position: (-12.5, -37.5, -37.5), size: 25.0, depth: 2 leaf: True, data: name: Node__201 position: (-5, -28, -29), name: Node__348 position: (-23, -27, -26), name: Node__365 position: (-10, -30, -27), name: Node__1484 position: (-12, -30, -30), name: Node__1493 position: (-9, -28, -26), name: Node__1808 position: (-16, -27, -26)
# 7 : position: (-18.75, -31.25, -18.75), size: 12.5, depth: 3 leaf: True, data: name: Node__141 position: (-22, -27, -16), name: Node__532 position: (-25, -28, -20), name: Node__664 position: (-17, -29, -18), name: Node__1303 position: (-17, -27, -14), name: Node__1451 position: (-23, -28, -20), name: Node__1580 position: (-24, -27, -23), name: Node__1901 position: (-24, -28, -24), name: Node__1949 position: (-14, -29, -25), name: Node__1984 position: (-21, -26, -15)
# 8 : position: (-18.75, -31.25, -6.25), size: 12.5, depth: 3 leaf: True, data: name: Node__192 position: (-21, -29, -4), name: Node__242 position: (-17, -28, -4), name: Node__591 position: (-22, -26, -9), name: Node__1285 position: (-18, -27, -10), name: Node__1680 position: (-21, -27, -9), name: Node__1756 position: (-16, -30, -8), name: Node__1799 position: (-13, -26, -2)
# 9 : position: (-6.25, -31.25, -18.75), size: 12.5, depth: 3 leaf: True, data: name: Node__203 position: (-10, -29, -19), name: Node__445 position: (-1, -28, -20), name: Node__585 position: (-3, -29, -17), name: Node__630 position: (-8, -29, -17), name: Node__1400 position: (-8, -27, -13), name: Node__1535 position: (-2, -28, -22), name: Node__1916 position: (-2, -30, -18)
# 10 : position: (-6.25, -31.25, -6.25), size: 12.5, depth: 3 leaf: True, data: name: Node__573 position: (-3, -28, -2), name: Node__837 position: (-1, -30, -12), name: Node__1121 position: (-2, -27, -6), name: Node__1184 position: (-8, -29, -8), name: Node__1728 position: (-11, -30, -12), name: Node__1784 position: (-1, -27, -9), name: Node__1860 position: (-12, -29, -10)
# 11 : position: (-18.75, -18.75, -31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__155 position: (-25, -16, -26), name: Node__455 position: (-19, -23, -29), name: Node__973 position: (-13, -25, -27), name: Node__1002 position: (-25, -13, -27), name: Node__1025 position: (-24, -16, -29), name: Node__1308 position: (-16, -21, -30), name: Node__1374 position: (-13, -21, -28), name: Node__1663 position: (-15, -16, -28)
# 12 : position: (-18.75, -6.25, -31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__593 position: (-20, -9, -30), name: Node__669 position: (-17, -12, -26), name: Node__1980 position: (-21, -6, -27)
# 13 : position: (-6.25, -18.75, -31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__232 position: (-1, -25, -30), name: Node__317 position: (-8, -16, -27), name: Node__517 position: (-9, -19, -30), name: Node__654 position: (-5, -22, -26), name: Node__1026 position: (-3, -20, -29), name: Node__1286 position: (-6, -21, -28), name: Node__1452 position: (-9, -14, -28)
# 14 : position: (-6.25, -6.25, -31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__156 position: (-7, -4, -26), name: Node__202 position: (-6, -9, -30), name: Node__216 position: (-12, -2, -26), name: Node__449 position: (-2, -10, -29), name: Node__494 position: (-4, -1, -26), name: Node__634 position: (-10, -2, -27), name: Node__647 position: (-11, -11, -29), name: Node__1295 position: (-8, -9, -28), name: Node__1646 position: (-2, -7, -27), name: Node__1749 position: (-2, -7, -26)
# 15 : position: (-21.875, -21.875, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node
-15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__657 position: (-8, -6, -15), name: Node__806 position: (-8, -1, -17), name: Node__997 position: (-12, -1, -16)
# 62 : position: (-3.125, -9.375, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__59 position: (-6, -10, -25), name: Node__704 position: (-5, -8, -21), name: Node__1169 position: (-6, -8, -23)
# 63 : position: (-3.125, -9.375, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__661 position: (-6, -8, -14), name: Node__867 position: (-6, -8, -13)
# 64 : position: (-3.125, -3.125, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__870 position: (-2, -1, -16)
# 65 : position: (-9.375, -9.375, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__115 position: (-7, -12, -7), name: Node__690 position: (-12, -8, -11), name: Node__1243 position: (-10, -12, -8), name: Node__1912 position: (-12, -10, -12)
# 66 : position: (-9.375, -9.375, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__512 position: (-7, -8, -2)
# 67 : position: (-9.375, -3.125, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__211 position: (-9, -1, -12)
# 68 : position: (-9.375, -3.125, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__941 position: (-10, -2, -4), name: Node__1729 position: (-7, -1, -1)
# 69 : position: (-3.125, -9.375, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__1131 position: (-4, -11, -5), name: Node__1304 position: (-3, -7, -1), name: Node__1593 position: (-6, -12, -4)
# 70 : position: (-3.125, -3.125, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__1983 position: (-2, -4, -9)
# 71 : position: (-3.125, -3.125, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__879 position: (-3, -1, -6), name: Node__1587 position: (-6, -4, -4)
# 72 : position: (-37.5, -37.5, 12.5), size: 25.0, depth: 2 leaf: True, data: name: Node__176 position: (-27, -29, 16), name: Node__947 position: (-28, -27, 19), name: Node__1032 position: (-29, -30, 24), name: Node__1666 position: (-29, -29, 24), name: Node__1795 position: (-28, -29, 6)
# 73 : position: (-28.125, -21.875, 3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__169 position: (-30, -24, 2), name: Node__658 position: (-26, -23, 6), name: Node__1413 position: (-26, -19, 6)
# 74 : position: (-28.125, -21.875, 9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__45 position: (-28, -24, 10), name: Node__251 position: (-29, -23, 8), name: Node__1218 position: (-29, -22, 9), name: Node__1414 position: (-29, -21, 9)
# 75 : position: (-28.125, -15.625, 3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__412 position: (-27, -14, 6), name: Node__695 position: (-28, -16, 0), name: Node__1057 position: (-26, -15, 5), name: Node__1946 position: (-30, -16, 2), name: Node__1990 position: (-28, -15, 6)
# 76 : position: (-28.125, -15.625, 9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__766 position: (-27, -15, 8), name: Node__785 position: (-27, -15, 7), name: Node__1091 position: (-28, -15, 9), name: Node__1177 position: (-30, -14, 9), name: Node__1607 position: (-27, -14, 11)
# 77 : position: (-31.25, -18.75, 18.75), size: 12.5, depth: 3 leaf: True, data: name: Node__182 position: (-27, -13, 13), name: Node__304 position: (-29, -23, 16), name: Node__316 position: (-30, -16, 24), name: Node__372 position: (-26, -21, 21), name: Node__1212 position: (-26, -13, 20), name: Node__1279 position: (-26, -23, 18), name: Node__1368 position: (-28, -14, 20), name: Node__1564 position: (-26, -23, 19)
# 78 : position: (-31.25, -6.25, 6.25), size: 12.5, depth: 3 leaf: True, data: name: Node__101 position: (-26, -9, 8), name: Node__363 position: (-26, -8, 8), name: Node__771 position: (-30, -6, 12), name: Node__1049 position: (-28, -5, 10), name: Node__1058 position: (-30, -8, 9)
# 79 : position: (-31.25, -6.25, 18.75), size: 12.5, depth: 3 leaf: True, data: name: Node__286 position: (-29, -6, 17), name: Node__686 position: (-26, -11, 18), name: Node__869 position: (-29, -3, 16), name: Node__1004 position: (-28, -4, 16), name: Node__1497 position: (-30, -11, 17), name: Node__1662 position: (-26, -12, 20)
# 80 : position: (-37.5, -12.5, 37.5), size: 25.0, depth: 2 leaf: True, data: name: Node__16 position: (-30, -21, 26), name: Node__288 position: (-27, -7, 28), name: Node__702 position: (-29, -4, 27), name: Node__894 position: (-27, -24, 26), name: Node__1031 position: (-28, -10, 29), name: Node__1307 position: (-28, -7, 29), name: Node__1421 position: (-28, -25, 29), name: Node__1582 position: (-30, -15, 25), name: Node__1862 position: (-30, -14, 29)
# 81 : position: (-21.875, -28.125, 3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__43 position: (-24, -30, 4)
# 82 : position: (-21.875, -28.125, 9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__74 position: (-21, -30, 10), name: Node__377 position: (-21, -29, 9), name: Node__987 position: (-23, -26, 7), name: Node__1460 position: (-19, -27, 9)
# 83 : position: (-15.625, -28.125, 3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__571 position: (-16, -27, 3), name: Node__1713 position: (-18, -28, 4)
# 84 : position: (-15.625, -28.125, 9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__161 position: (-18, -29, 10), name: Node__1040 position: (-17, -26, 12), name: Node__1343 position: (-15, -27, 12), name: Node__1612 position: (-16, -30, 12), name: Node__1869 position: (-14, -26, 7), name: Node__1885 position: (-16, -29, 10)
# 85 : position: (-18.75, -31.25, 18.75), size: 12.5, depth: 3 leaf: True, data: name: Node__134 position: (-14, -29, 22), name: Node__431 position: (-15, -28, 13), name: Node__945 position: (-15, -27, 17), name: Node__1022 position: (-24, -27, 13), name: Node__1300 position: (-19, -30, 19), name: Node__1525 position: (-20, -27, 15), name: Node__1765 position: (-17, -27, 15), name: Node__1852 position: (-19, -30, 19)
# 86 : position: (-6.25, -31.25, 6.25), size: 12.5, depth: 3 leaf: True, data: name: Node__34 position: (-8, -29, 5), name: Node__66 position: (-12, -30, 10), name: Node__130 position: (-4, -27, 5), name: Node__414 position: (-8, -29, 4), name: Node__520 position: (-11, -30, 1), name: Node__1168 position: (-3, -28, 6), name: Node__1518 position: (-8, -29, 4), name: Node__1764 position: (-3, -26, 7), name: Node__1771 position: (-6, -30, 1), name: Node__1948 position: (-6, -26, 0)
# 87 : position: (-6.25, -31.25, 18.75), size: 12.5, depth: 3 leaf: True, data: name: Node__633 position: (-8, -28, 22), name: Node__652 position: (-6, -30, 21), name: Node__723 position: (-4, -27, 20), name: Node__780 position: (-10, -27, 22), name: Node__1173 position: (-4, -29, 14), name: Node__1422 position: (-7, -29, 13), name: Node__1847 position: (-11, -27, 18), name: Node__1942 position: (-8, -29, 20)
# 88 : position: (-12.5, -37.5, 37.5), size: 25.0, depth: 2 leaf: True, data: name: Node__398 position: (-21, -26, 25), name: Node__399 position: (-4, -29, 29), name: Node__922 position: (-15, -30, 25), name: Node__1510 position: (-13, -30, 27), name: Node__1881 position: (-11, -26, 28)
# 89 : position: (-21.875, -21.875, 3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__208 position: (-22, -24, 4), name: Node__586 position: (-24, -23, 4), name: Node__977 position: (-25, -21, 4), name: Node__1496 position: (-21, -19, 3)
# 90 : position: (-21.875, -21.875, 9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__168 position: (-24, -22, 11), name: Node__1239 position: (-21, -21, 12)
# 91 : position: (-21.875, -15.625, 3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__1978 position: (-20, -17, 3)
# 92 : position: (-21.875, -15.625, 9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__
 9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__883 position: (-9, -9, 11)
# 137 : position: (-9.375, -3.125, 3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__1369 position: (-12, -1, 2), name: Node__1622 position: (-12, -2, 6)
# 138 : position: (-9.375, -3.125, 9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__120 position: (-10, -1, 10)
# 139 : position: (-3.125, -9.375, 3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__842 position: (-5, -12, 0), name: Node__1021 position: (-6, -7, 5)
# 140 : position: (-3.125, -9.375, 9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__95 position: (-1, -10, 7), name: Node__160 position: (-4, -11, 7), name: Node__479 position: (-6, -12, 11), name: Node__1471 position: (-6, -9, 7)
# 141 : position: (-3.125, -3.125, 3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__245 position: (-2, -5, 4), name: Node__1830 position: (-4, -2, 0)
# 142 : position: (-3.125, -3.125, 9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__788 position: (-3, -1, 8), name: Node__896 position: (-2, -5, 12), name: Node__1059 position: (-1, -6, 11), name: Node__1618 position: (-1, -3, 9)
# 143 : position: (-6.25, -6.25, 18.75), size: 12.5, depth: 3 leaf: True, data: name: Node__291 position: (-11, -12, 16), name: Node__360 position: (-12, -11, 16), name: Node__478 position: (-12, -5, 15), name: Node__598 position: (-5, -6, 14), name: Node__731 position: (-5, -2, 20), name: Node__1427 position: (-11, -1, 17), name: Node__1437 position: (-10, -9, 14)
# 144 : position: (-18.75, -18.75, 31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__91 position: (-21, -21, 26), name: Node__270 position: (-25, -14, 27), name: Node__361 position: (-21, -24, 25), name: Node__539 position: (-14, -25, 25), name: Node__600 position: (-23, -15, 28), name: Node__757 position: (-16, -22, 28), name: Node__798 position: (-21, -14, 26), name: Node__1277 position: (-21, -23, 29), name: Node__1672 position: (-16, -20, 26), name: Node__1759 position: (-19, -17, 29)
# 145 : position: (-18.75, -6.25, 31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__81 position: (-19, -4, 29), name: Node__128 position: (-17, -6, 28), name: Node__196 position: (-22, -6, 25), name: Node__235 position: (-16, -8, 25), name: Node__254 position: (-20, -12, 27), name: Node__367 position: (-21, -3, 26), name: Node__1531 position: (-14, -4, 27)
# 146 : position: (-6.25, -18.75, 31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__484 position: (-2, -24, 27), name: Node__499 position: (-6, -25, 28), name: Node__791 position: (-1, -22, 25), name: Node__1273 position: (-10, -21, 26)
# 147 : position: (-6.25, -6.25, 31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__58 position: (-3, -8, 26), name: Node__187 position: (-4, -1, 29), name: Node__342 position: (-9, -12, 29), name: Node__380 position: (-12, -1, 25), name: Node__813 position: (-12, -7, 26), name: Node__1345 position: (-3, -11, 29), name: Node__1545 position: (-6, -3, 27), name: Node__1616 position: (-6, -7, 29)
# 148 : position: (-37.5, 12.5, -37.5), size: 25.0, depth: 2 leaf: True, data: name: Node__424 position: (-30, 2, -28), name: Node__434 position: (-29, 0, -26), name: Node__518 position: (-28, 19, -28), name: Node__1215 position: (-28, 12, -27), name: Node__1302 position: (-27, 21, -28), name: Node__1378 position: (-30, 16, -30), name: Node__1556 position: (-29, 24, -26)
# 149 : position: (-28.125, 3.125, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__500 position: (-29, 2, -25), name: Node__961 position: (-27, 2, -25), name: Node__1461 position: (-27, 4, -23)
# 150 : position: (-28.125, 3.125, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__932 position: (-28, 0, -15), name: Node__1245 position: (-29, 0, -14), name: Node__1867 position: (-26, 2, -17)
# 151 : position: (-28.125, 9.375, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__542 position: (-29, 7, -22), name: Node__1209 position: (-30, 7, -22), name: Node__1712 position: (-28, 7, -22)
# 152 : position: (-28.125, 9.375, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__1731 position: (-28, 7, -13), name: Node__1890 position: (-30, 12, -13), name: Node__1892 position: (-30, 8, -18)
# 153 : position: (-31.25, 6.25, -6.25), size: 12.5, depth: 3 leaf: True, data: name: Node__488 position: (-30, 5, -7), name: Node__759 position: (-28, 11, -1), name: Node__777 position: (-30, 10, -2), name: Node__778 position: (-28, 7, -1), name: Node__1141 position: (-28, 4, -2), name: Node__1152 position: (-30, 7, -9), name: Node__1433 position: (-30, 0, -12)
# 154 : position: (-28.125, 15.625, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__632 position: (-30, 15, -24)
# 155 : position: (-28.125, 15.625, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__1305 position: (-30, 17, -13)
# 156 : position: (-28.125, 21.875, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__8 position: (-28, 19, -24), name: Node__26 position: (-30, 20, -20), name: Node__439 position: (-30, 21, -19)
# 157 : position: (-28.125, 21.875, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__24 position: (-28, 20, -15), name: Node__527 position: (-26, 22, -13), name: Node__560 position: (-26, 24, -15), name: Node__957 position: (-30, 22, -15), name: Node__1166 position: (-26, 21, -15), name: Node__1988 position: (-27, 22, -14)
# 158 : position: (-31.25, 18.75, -6.25), size: 12.5, depth: 3 leaf: True, data: name: Node__30 position: (-29, 20, -2), name: Node__189 position: (-28, 23, -2), name: Node__709 position: (-26, 24, -11), name: Node__1009 position: (-29, 23, -5), name: Node__1324 position: (-26, 14, -6), name: Node__1375 position: (-27, 13, -10), name: Node__1673 position: (-29, 23, -2)
# 159 : position: (-37.5, 37.5, -37.5), size: 25.0, depth: 2 leaf: True, data: name: Node__318 position: (-30, 26, -28), name: Node__1681 position: (-28, 28, -26), name: Node__1972 position: (-30, 26, -28)
# 160 : position: (-37.5, 37.5, -12.5), size: 25.0, depth: 2 leaf: True, data: name: Node__525 position: (-30, 29, -16), name: Node__534 position: (-29, 29, -19), name: Node__978 position: (-30, 27, -21), name: Node__1435 position: (-26, 25, -8), name: Node__1550 position: (-30, 26, -20), name: Node__1632 position: (-27, 26, -22), name: Node__1815 position: (-27, 26, -13)
# 161 : position: (-18.75, 6.25, -31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__127 position: (-17, 0, -30), name: Node__224 position: (-14, 4, -29), name: Node__388 position: (-19, 2, -30), name: Node__962 position: (-18, 12, -30), name: Node__1533 position: (-22, 0, -28)
# 162 : position: (-18.75, 18.75, -31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__347 position: (-24, 23, -27), name: Node__572 position: (-24, 19, -30), name: Node__942 position: (-21, 16, -27), name: Node__1065 position: (-22, 13, -28), name: Node__1225 position: (-21, 13, -28), name: Node__1584 position: (-20, 15, -26)
# 163 : position: (-6.25, 6.25, -31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__171 position: (-7, 9, -28), name: Node__280 position: (-2, 1, -30), name: Node__829 position: (-11, 12, -26), name: Node__1119 position: (-7, 3, -26), name: Node__1133 position: (-7, 6, -28), name: Node__1163 position: (-11, 0, -28), name: Node__1516 position: (-2, 1, -26), name: Node__1613 position: (-9, 8, -29), name: Node__1678 position: (-4, 5, -26), name: Node__1921 position: (-2, 8, -30)
# 164 : position: (-6.25, 18.75, -31.25), size: 12.5, depth: 3 leaf: True, data: name: Node__114 position: (-1, 18, -28), name: Node__410 position: (-3, 13, -26), name: Node__509 position: (-5, 18, -27), name: Node__811 position: (-1, 18, -28), name: Node__833 position: (-4, 16, -28), name: Node__996 position: (-5, 14, -27)
# 165 : position: (-21.875, 3.125, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__1560 position: (-23, 3, -23), name: Node__1879 position: (-23, 0, -23)
# 166 : position: (-21.875, 3.125, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__720 position: (-20, 6, -17), name: Node__831 position: (-20, 2, -15), name: Node__1271 position: (-22, 5, -13), name: Node__1391 position: (-19, 6, -15), name: Node__1442 position: (-22, 3, -15), name: Node__1913 position: (-22, 6, -14)
# 167 : position: (-21.875, 9.375, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__1532 position: (-20, 7, -21), name: Node__1932 position: (-25, 9, -20)
# 168 : position: (-21.875, 9.375, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__1200 position: (-25, 8, -14), name: Node__1330 position: (-25, 8, -13)
# 169 : position: (-15.625, 3.125, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__673 position: (-15, 3, -22), name: Node__1182 position: (-13, 6, -21)
# 170 : position: (-15.625, 3.125, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__100 position: (-18, 4, -17), name: Node__1467 position: (-15, 6, -16), name: Node__1822 position: (-15, 0, -17)
# 171 : position: (-15.625, 9.375, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__258 position: (-13, 7, -22), name: Node__956 position: (-16, 9, -19), name: Node__1840 position: (-16, 12, -24)
# 172 : position: (-15.625, 9.375, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__226 position: (-16, 9, -16), name: Node__818 position: (-15, 9, -17), name: Node__986 position: (-16, 11, -17)
# 173 : position: (-21.875, 3.125, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__843 position: (-23, 4, -9), name: Node__944 position: (-23, 4, -9), name: Node__1792 position: (-21, 1, -11)
# 174 : position: (-21.875, 3.125, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__1952 position: (-20, 4, -4)
# 175 : position: (-21.875, 9.375, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__135 position: (-20, 11, -8), name: Node__1155 position: (-24, 12, -8), name: Node__1541 position: (-21, 12, -12)
# 176 : position: (-21.875, 9.375, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__98 position: (-24, 10, -3), name: Node__331 position: (-22, 10, -5)
# 177 : position: (-15.625, 3.125, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__139 position: (-13, 1, -8), name: Node__1802 position: (-16, 6, -11)
# 178 : position: (-15.625, 3.125, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__1005 position: (-18, 4, -6), name: Node__1039 position: (-17, 4, -4)
# 179 : position: (-15.625, 9.375, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__902 position: (-18, 10, -7), name: Node__1900 position: (-16, 11, -12)
# 180 : position: (-15.625, 9.375, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__143 position: (-15, 9, -3)
# 181 : position: (-21.875, 15.625, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__173 position: (-25, 13, -21), name: Node__700 position: (-23, 18, -25), name: Node__910 position: (-23, 17, -21), name: Node__1203 position: (-21, 18, -25)
# 182 : position: (-21.875, 15.625, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__827 position: (-23, 17, -18), name: Node__895 position: (-21, 18, -18)
# 183 : position: (-21.875, 21.875, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__104 position: (-20, 19, -22), name: Node__106 position: (-23, 23, -19), name: Node__194 position: (-23, 24, -22), name: Node__1007 position: (-23, 23, -25), name: Node__1223 position: (-23, 19, -22)
# 184 : position: (-15.625, 15.625, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__89 position: (-18, 17, -22)
# 185 : position: (-15.625, 15.625, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__854 position: (-18, 14, -18)
# 186 : position: (-15.625, 21.875, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__737 position: (-14, 20, -19)
# 187 : position: (-21.875, 15.625, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__1037 position: (-20, 18, -9), name: Node__1318 position: (-19, 15, -9)
# 188 : position: (-21.875, 15.625, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__446 position: (-23, 17, -3)
# 189 : position: (-21.875, 21.875, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__1001 position: (-23, 22, -12), name: Node__1994 position: (-20, 20, -10)
# 190 : position: (-21.875, 21.875, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__748 position: (-23, 23, -5), name: Node__1068 position: (-25, 20, -3), name: Node__1462 position: (-23, 21, -4)
# 191 : position: (-15.625, 15.625, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__909 position: (-15, 13, -7), name: Node__1154 position: (-16, 17, -8), name: Node__1179 position: (-18, 15, -11), name: Node__1566 position: (-18, 15, -12)
# 192 : position: (-15.625, 15.625, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__121 position: (-14, 17, -6), name: Node__802 position: (-15, 18, -2), name: Node__1136 position: (-15, 13, -4)
# 193 : position: (-15.625, 21.875, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__247 position: (-13, 21, -7)
# 194 : position: (-15.625, 21.875, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__14 position: (-14, 22, -2)
# 195 : position: (-9.375, 3.125, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__400 position: (-8, 3, -25), name: Node__688 position: (-10, 5, -20), name: Node__1066 position: (-12, 6, -20), name: Node__1480 position: (-12, 3, -24)
# 196 : position: (-9.375, 3.125, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__865 position: (-9, 0, -16), name: Node__1536 position: (-11, 3, -13), name: Node__1790 position: (-12, 4, -18), name: Node__1856 position: (-10, 3, -15)
# 197 : position: (-9.375, 9.375, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__681 position: (-8, 12, -25), name: Node__694 position: (-11, 7, -22), name: Node__1483 position: (-8, 9, -24)
# 198 : position: (-9.375, 9.375, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__473 position: (-11, 12, -16), name: Node__1111 position: (-12, 7, -16)
# 199 : position: (-3.125, 3.125, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__38 position: (-4, 0, -24), name: Node__850 position: (-1, 2, -19), name: Node__1159 position: (-6, 1, -23), name: Node__1512 position: (-2, 5, -23), name: Node__1845 position: (-5, 6, -23)
# 200 : position: (-3.125, 3.125, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__885 position: (-2, 0, -18)
# 201 : position: (-3.125, 9.375, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__1333 position: (-4, 12, -21)
# 202 : position: (-3.125, 9.375, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__362 position: (-4, 9, -18), name: Node__533 position: (-4, 11, -15), name: Node__1410 position: (-4, 9, -13)
# 203 : position: (-9.375, 3.125, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__378 position: (-10, 1, -12), name: Node__729 position: (-10, 3, -10), name: Node__758 position: (-11, 5, -7), name: Node__1506 position: (-7, 0, -12)
# 204 : position: (-9.375, 3.125, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__85 position: (-7, 2, -5), name: Node__1561 position: (-11, 1, -3)
# 205 : position: (-9.375, 9.375, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__129 position: (-10, 11, -10)
# 206 : position: (-9.375, 9.375, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__1854 position: (-11, 11, -4)
# 207 : position: (-3.125, 3.125, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__469 position: (-6, 6, -11), name: Node__772 position: (-1, 5, -7), name: Node__1961 position: (-6, 0, -12)
# 208 : position: (-3.125, 3.125, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__794 position: (-5, 5, -5), name: Node__938 position: (-1, 0, -4), name: Node__1162 position: (-3, 5, -5)
# 209 : position: (-3.125, 9.375, -9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__736 position: (-5, 7, -9), name: Node__974 position: (-2, 12, -10)
# 210 : position: (-3.125, 9.375, -3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__991 position: (-5, 11, -4)
# 211 : position: (-9.375, 15.625, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__1301 position: (-10, 17, -24)
# 212 : position: (-9.375, 15.625, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__408 position: (-10, 14, -13)
# 213 : position: (-9.375, 21.875, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__1878 position: (-9, 19, -20)
# 214 : position: (-9.375, 21.875, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__1804 position: (-9, 19, -18)
# 215 : position: (-3.125, 15.625, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__390 position: (-6, 13, -25), name: Node__606 position: (-6, 15, -19), name: Node__1812 position: (-5, 17, -22)
# 216 : position: (-3.125, 15.625, -15.625), size: 6.25, depth: 4 leaf: True, data: name: Node__421 position: (-3, 16, -18), name: Node__1647 position: (-1, 16, -13), name: Node__1788 position: (-2, 16, -13)
# 217 : position: (-3.125, 21.875, -21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__40 position: (-5, 22, -19), name: Node__1113 position: (-2, 23, -23), name: Node__1835 position: (-4, 20, -23), name: Node__1884 position: (-4, 24, -25), name: Node__1930 position: (-4, 21, -20)
# ...
# 1633 : position: (17.1875, 10.9375, 7.8125), size: 3.125, depth: 5 leaf: True, data: name: Node__174 position: (16, 11, 8)
# 1634 : position: (17.1875, 10.9375, 10.9375), size: 3.125, depth: 5 leaf: True, data: name: Node__67 position: (16, 10, 11)
# 1635 : position: (21.875, 3.125, 3.125), size: 6.25, depth: 4 leaf: True, data: name: Node__1284 position: (20, 1, 6)
# 1636 : position: (21.875, 3.125, 9.375), size: 6.25, depth: 4 leaf: True, data: name: Node__1521 position: (19, 6, 9)
# 1637 : position: (20.3125, 7.8125, 1.5625), size: 3.125, depth: 5 leaf: True, data: name: Node__287 position: (20, 7, 3)
# 1638 : position: (23.4375, 10.9375, 4.6875), size: 3.125, depth: 5 leaf: True, data: name: Node__103 position: (23, 12, 5)
# 1639 : position: (14.0625, 1.5625, 17.1875), size: 3.125, depth: 5 leaf: True, data: name: Node__1515 position: (15, 0, 17)
# 1640 : position: (17.1875, 4.6875, 17.1875), size: 3.125, depth: 5 leaf: True, data: name: Node__1073 position: (18, 4, 16)
# 1641 : position: (15.625, 3.125, 21.875), size: 6.25, depth: 4 leaf: True, data: name: Node__393 position: (16, 0, 20)
# 1642 : position: (14.0625, 10.9375, 14.0625), size: 3.125, depth: 5 leaf: True, data: name: Node__124 position: (15, 10, 14)
# 1643 : position: (17.1875, 7.8125, 14.0625), size: 3.125, depth: 5 leaf: True, data: name: Node__374 position: (18, 9, 15)
# 1644 : position: (17.1875, 7.8125, 17.1875), size: 3.125, depth: 5 leaf: True, data: name: Node__1244 position: (17, 7, 16)
# 1645 : position: (20.3125, 1.5625, 20.3125), size: 3.125, depth: 5 leaf: True, data: name: Node__677 position: (20, 3, 21)
# 1646 : position: (20.3125, 4.6875, 23.4375), size: 3.125, depth: 5 leaf: True, data: name: Node__1071 position: (19, 6, 23)
# 1647 : position: (23.4375, 1.5625, 23.4375), size: 3.125, depth: 5 leaf: True, data: name: Node__1724 position: (23, 0, 22)
# 1648 : position: (23.4375, 4.6875, 23.4375), size: 3.125, depth: 5 leaf: True, data: name: Node__1987 position: (24, 4, 22)
# 1649 : position: (20.3125, 7.8125, 14.0625), size: 3.125, depth: 5 leaf: True, data: name: Node__1883 position: (20, 7, 13)
# 1650 : position: (20.3125, 7.8125, 17.1875), size: 3.125, depth: 5 leaf: True, data: name: Node__1543 position: (21, 7, 18)
# 1651 : position: (20.3125, 10.9375, 17.1875), size: 3.125, depth: 5 leaf: True, data: name: Node__764 position: (19, 12, 16)
# 1652 : position: (20.3125, 7.8125, 23.4375), size: 3.125, depth: 5 leaf: True, data: name: Node__256 position: (21, 7, 22)
# 1653 : position: (20.3125, 10.9375, 20.3125), size: 3.125, depth: 5 leaf: True, data: name: Node__35 position: (19, 10, 19), name: Node__984 position: (20, 11, 20), name: Node__1594 position: (21, 11, 21), name: Node__1798 position: (21, 11, 21)
# 1654 : position: (14.0625, 17.1875, 4.6875), size: 3.125, depth: 5 leaf: True, data: name: Node__39 position: (15, 18, 5)
# 1655 : position: (17.1875, 14.0625, 1.5625), size: 3.125, depth: 5 leaf: True, data: name: Node__866 position: (18, 15, 3)
# 1656 : position: (17.1875, 17.1875, 1.5625), size: 3.125, depth: 5 leaf: True, data: name: Node__75 position: (16, 18, 3)
# 1657 : position: (17.1875, 14.0625, 7.8125), size: 3.125, depth: 5 leaf: True, data: name: Node__432 position: (17, 13, 7)
# 1658 : position: (17.1875, 17.1875, 10.9375), size: 3.125, depth: 5 leaf: True, data: name: Node__145 position: (18, 17, 10)
# 1659 : position: (14.0625, 23.4375, 1.5625), size: 3.125, depth: 5 leaf: True, data: name: Node